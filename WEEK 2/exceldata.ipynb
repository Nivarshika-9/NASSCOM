# %%
import pandas as pd
df=pd.read_csv("/content/Untitled spreadsheet - Sheet1.csv")
df.head()
# Out:
#          Name  Age     Roll no
# 0  Nivarshika   19  25WH1A05BK
# 1   Vaishnavi   20  25WH1A05BL
# 2     Shravya   18  25WH1A05BM
# 3      Hasini   20  25WH1A05BC
# 4      Reethi   19  25WH1A05AG
